# %% [markdown]
# <a href="https://colab.research.google.com/github/Putri-Adinda-Kumalasari/breast-cancer-classification/blob/main/breast_cancer_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ekstraksi file
path1 = '/content/breast+cancer+wisconsin+diagnostic.zip'
path2 = '/content/tugas dibimbing'

# %%
from zipfile import ZipExtFile
with ZipFile(path1, 'r') as zipobj:
  zipobj.extractall(path2)

# %%
# import library
import pandas as pd

data = pd.read_csv('/content/tugas dibimbing/wdbc.data')
data.head()
# Out:
#      842302  M  17.99  10.38   122.8    1001   0.1184   0.2776  0.3001  \
# 0    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 1  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 2  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 3  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
# 4    843786  M  12.45  15.70   82.57   477.1  0.12780  0.17000  0.1578
#
#     0.1471  ...  25.38  17.33   184.6    2019  0.1622  0.6656  0.7119  0.2654  \
# 0  0.07017  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 1  0.12790  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 2  0.10520  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 3  0.10430  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
# 4  0.08089  ...  15.47  23.75  103.40   741.6  0.1791  0.5249  0.5355  0.1741
#
#    0.4601   0.1189
# 0  0.2750  0.08902
# 1  0.3613  0.08758
# ...

# %%
# eksplorasi data
data.drop('842302', axis=1, inplace=True)
data.head()
# Out:
#    M  17.99  10.38   122.8    1001   0.1184   0.2776  0.3001   0.1471  0.2419  \
# 0  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869  0.07017  0.1812
# 1  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974  0.12790  0.2069
# 2  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414  0.10520  0.2597
# 3  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980  0.10430  0.1809
# 4  M  12.45  15.70   82.57   477.1  0.12780  0.17000  0.1578  0.08089  0.2087
#
#    ...  25.38  17.33   184.6    2019  0.1622  0.6656  0.7119  0.2654  0.4601  \
# 0  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860  0.2750
# 1  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430  0.3613
# 2  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575  0.6638
# 3  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625  0.2364
# 4  ...  15.47  23.75  103.40   741.6  0.1791  0.5249  0.5355  0.1741  0.3985
#
#     0.1189
# 0  0.08902
# ...

# %%
data.isna().sum()
# Out:
# M           0
# 17.99       0
# 10.38       0
# 122.8       0
# 1001        0
# 0.1184      0
# 0.2776      0
# 0.3001      0
# 0.1471      0
# 0.2419      0
# 0.07871     0
# 1.095       0
# 0.9053      0
# 8.589       0
# 153.4       0
# 0.006399    0
# 0.04904     0
# 0.05373     0
# 0.01587     0
# 0.03003     0
# 0.006193    0
# 25.38       0
# 17.33       0
# 184.6       0
# 2019        0
# 0.1622      0
# 0.6656      0
# 0.7119      0
# 0.2654      0
# 0.4601      0
# 0.1189      0
# dtype: int64

# %% [markdown]
# **Read Dataset**

# %%
import pandas as pd
from sklearn import datasets

# Memuat dataset breast cancer dari scikit-learn dan mengonversinya menjadi DataFrame
breast_cancer = datasets.load_breast_cancer()

X = breast_cancer.data
y = breast_cancer.target

# Mengonversi data fitur dan target menjadi DataFrame
df_X = pd.DataFrame(X, columns=breast_cancer.feature_names)
df_y = pd.DataFrame(y, columns=['target'])

# Gabungkan fitur dan target dalam satu DataFrame
df = pd.concat([df_X, df_y], axis=1)

df.head (10)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
# 5        12.45         15.70           82.57      477.1          0.12780
# 6        18.25         19.98          119.60     1040.0          0.09463
# 7        13.71         20.83           90.20      577.9          0.11890
# 8        13.00         21.82           87.50      519.8          0.12730
# 9        12.46         24.04           83.97      475.9          0.11860
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760         0.30010              0.14710         0.2419
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
df['target'].unique()
# Out:
# array([0, 1])

# %%
df.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer()
data.target[[10, 50, 85]]
list(data.target_names)
# Out:
# ['malignant', 'benign']

# %% [markdown]
# **Split Data**

# %%
from sklearn.model_selection import train_test_split

# Membagi data menjadi train dan test
X_train, X_test, y_train, y_test = train_test_split(df_X, df_y, test_size = 0.2, random_state = 42)

# %% [markdown]
# **Train the Model**

# %%
from sklearn.tree import DecisionTreeClassifier

# Membuat dan melatih model Decision Tree
model = DecisionTreeClassifier(random_state=36)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=36)

# %% [markdown]
# **Predict and Evaluate**

# %%
from sklearn.metrics import accuracy_score

# Memprediksi dan mengevaluasi data
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)

print("Laporan Klasifikasi:")
print(f"akurasi : {accuracy * 100:.2f}%")
# Out:
# Laporan Klasifikasi:
# akurasi : 92.98%

# %%
import matplotlib.pyplot as plt
from sklearn import tree

# Visualisasi decission tree
plt.figure(figsize=(15, 10))
tree.plot_tree(model, feature_names=breast_cancer.feature_names, class_names=breast_cancer.target_names, filled=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# Create a random number generator with a fixed seed for reproducibility
rng = np.random.default_rng(19680801)

# %%
N_points = 569
n_bins = 30

# Generate two normal distributions
dist1 = rng.standard_normal(N_points)
dist2 = 0.4 * rng.standard_normal(N_points) + 5

fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)

# We can set the number of bins with the *bins* keyword argument.
axs[0].hist(dist1, bins=n_bins)
axs[1].hist(dist2, bins=n_bins)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

jenis_kanker = ["benign",
                "malignant"]

data = [1,1] # Placeholder data, replace with actual data if available
ingredients = jenis_kanker


def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return f"{pct:.1f}%\n({absolute:d})"


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))

ax.legend(wedges, jenis_kanker,
          title="jenis kanker",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=8, weight="bold")

ax.set_title("breast cancer classification")

plt.show()

# %% [markdown]
# **Visualisasi distribusi kelas target**

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer

# Load dataset
data = load_breast_cancer()
labels = data.target_names  # ['malignant', 'benign']
values = [sum(data.target == 0), sum(data.target == 1)]  # Jumlah masing-masing kelas

# Membuat pie chart
plt.figure(figsize=(6, 6))
plt.pie(values, labels=labels, autopct='%1.1f%%', colors=['red', 'green'], startangle=90, shadow=True)
plt.title("Distribusi Kelas Target (Malignant vs Benign)")
plt.show()

# %%
import seaborn as sns
import pandas as pd

# Konversi ke DataFrame
df = pd.DataFrame({'Target': data.target})
df['Target'] = df['Target'].map({0: 'Malignant', 1: 'Benign'})  # Mapping label

# Membuat bar plot
plt.figure(figsize=(6, 4))
sns.countplot(x=df['Target'], palette=['red', 'green'])
plt.title("Distribusi Kelas Target")
plt.xlabel("Kelas")
plt.ylabel("Jumlah Sampel")
plt.show()
# Out:
# <ipython-input-2-7345686e7fd9>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['Target'], palette=['red', 'green'])

# %% [markdown]
# **Visualisasi menggunakan histogram dan KDE plot**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_breast_cancer

# Load dataset
data = load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)  # Buat DataFrame

# Plot histogram untuk 'mean radius'
plt.figure(figsize=(8, 5))
sns.histplot(df['mean radius'], bins=30, kde=False, color='blue')
plt.title('Histogram Distribusi Mean Radius')
plt.xlabel('Mean Radius')
plt.ylabel('Jumlah Sampel')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.kdeplot(df['mean radius'], fill=True, color='purple', alpha=0.5)
plt.title('KDE Plot Distribusi Mean Radius')
plt.xlabel('Mean Radius')
plt.ylabel('Density')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['mean radius'], bins=30, kde=True, color='green')
plt.title('Histogram + KDE Plot untuk Mean Radius')
plt.xlabel('Mean Radius')
plt.ylabel('Frekuensi / Density')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_breast_cancer

# Load dataset
data = load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['Target'] = data.target  # 0 = Malignant, 1 = Benign
df['Target'] = df['Target'].map({0: 'Malignant', 1: 'Benign'})  # Ubah label angka jadi teks

# Plot Histogram berdasarkan kelas target
plt.figure(figsize=(8, 5))
sns.histplot(df, x='mean radius', hue='Target', bins=30, kde=True, palette={'Malignant': 'red', 'Benign': 'green'}, alpha=0.6)
plt.title('Distribusi Mean Radius Berdasarkan Kelas Kanker')
plt.xlabel('Mean Radius')
plt.ylabel('Frekuensi / Density')
plt.legend(title="Kelas Kanker")
plt.show()
# Out:
# <ipython-input-5-8aac9cf15c25>:18: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title="Kelas Kanker")

# %% [markdown]
# **Visualisasi confusion matrix**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# 1️⃣ Load dataset
data = load_breast_cancer()
X = data.data  # Fitur (30 fitur)
y = data.target  # Target (0 = Malignant, 1 = Benign)

# 2️⃣ Normalisasi fitur menggunakan StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3️⃣ Split data: 80% training, 20% testing
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42, stratify=y)

# 4️⃣ Melatih model Logistic Regression
model = LogisticRegression()
model.fit(X_train, y_train)

# 5️⃣ Prediksi pada data uji
y_pred = model.predict(X_test)

# 6️⃣ Evaluasi Model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# 7️⃣ Print hasil evaluasi
print(f"✅ Akurasi Model: {accuracy:.4f}")
print("\n🔍 Classification Report:\n", class_report)

# 8️⃣ Visualisasi Confusion Matrix
plt.figure(figsize=(5,4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=data.target_names, yticklabels=data.target_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# ✅ Akurasi Model: 0.9825
#
# 🔍 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        42
#            1       0.99      0.99      0.99        72
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_breast_cancer

# load datasets
data = load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['Target'] = data.target #  0 = Malignant, 1 = Benign

# calculate the correlation matrix
corr_matrix = df.corr() #this line is added to calculate the correlation matrix

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix[['Target']].sort_values(by='Target', ascending=False), annot=True, cmap="coolwarm", linewidths=0.5, vmin=-1, vmax=1)
plt.title("Korelasi Fitur dengan Kelas Kanker (Benign/Malignant)")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer

# Load dataset
data = load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['Target'] = data.target

# Hitung korelasi dengan target
correlation = df.corr()['Target'].drop('Target').sort_values(ascending=False)

# Tampilkan fitur dengan korelasi tertinggi
plt.figure(figsize=(8, 6))
sns.barplot(y=correlation.index[:10], x=correlation.values[:10], palette='coolwarm')
plt.xlabel("Korelasi dengan Target")
plt.ylabel("Feature")
plt.title("Top 10 Fitur dengan Korelasi Tertinggi dengan Target")
plt.show()

# Pilih fitur dengan korelasi > 0.4
selected_features_corr = correlation[correlation > 0.4].index.tolist()
print("Fitur Terpilih (Korelasi > 0.4):", selected_features_corr)
# Out:
# <ipython-input-10-1cfc32b55118>:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=correlation.index[:10], x=correlation.values[:10], palette='coolwarm')
# Fitur Terpilih (Korelasi > 0.4): []
